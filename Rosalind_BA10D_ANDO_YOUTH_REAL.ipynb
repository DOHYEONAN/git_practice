# %% [markdown]
# <a href="https://colab.research.google.com/github/DOHYEONAN/git_practice/blob/master/Rosalind_BA10D_ANDO_YOUTH_REAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title
## http://rosalind.info/problems/ba10d/

sample_data_list = """
xzyyzzyzyy
--------
x   y   z
--------
A   B
--------
    A   B
A   0.641   0.359 
B   0.729   0.271 
--------
    x   y   z
A   0.117   0.691   0.192 
B   0.097   0.42   0.483
""".strip().split("\n")

outcome_str = sample_data_list[0]
outcome_list = sample_data_list[2].strip().split()
status_list = sample_data_list[4].strip().split()

status_header = sample_data_list[6].strip().split()
transit_start_line = 7
transit_end_line = transit_start_line + len(status_list)

transit_list = dict()
for tmp_line in sample_data_list[transit_start_line:transit_end_line]:
  tmp_tokens = tmp_line.strip().split()
  for tmp_i in range(1,len(tmp_tokens)):
    transit_code = '%s%s' % (tmp_tokens[0], status_header[tmp_i-1])
    transit_list[transit_code] = float(tmp_tokens[tmp_i])

emit_start_line = transit_end_line + len(status_list)
emit_end_line = emit_start_line + len(outcome_list)-1
outcome_header = sample_data_list[emit_start_line-1].strip().split()

emit_list = dict()
for tmp_line in sample_data_list[emit_start_line:emit_end_line]:
  print(tmp_line)
  tmp_tokens = tmp_line.strip().split()
  for tmp_i in range(1,len(tmp_tokens)):
    emit_code = '%s%s' % (tmp_tokens[0], outcome_header[tmp_i-1])
    emit_list[emit_code] = float(tmp_tokens[tmp_i])

print(transit_list)
print(emit_list)


#My_Code

interest = "xyxzzxyxyy"
alphabet = []
result = 1

temporal_1 = 1
temporal_2 = 1
temporal_3 = 1
temporal_4 = 1


for i in range(len(interest)):
  
  # Boundary_1_0
  
  if interest[i] == 'x':
    if i == 0:
      if interest[i+1] == 'x':
        temporal_1 *= 0.5 * emit_list['Ax'] * transit_list['AA'] * emit_list['Ax'] 
        temporal_2 *= 0.5 * emit_list['Ax'] * transit_list['AB'] * emit_list['Bx']
        temporal_3 *= 0.5 * emit_list['Bx'] * transit_list['BA'] * emit_list['Ax']
        temporal_4 *= 0.5 * emit_list['Bx'] * transit_list['BB'] * emit_list['Bx']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Ax']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['Bx']
          alphabet.append('B')
          
      elif interest[i+1] == 'y':
        temporal_1 *= 0.5 * emit_list['Ax'] * transit_list['AA'] * emit_list['Ay'] 
        temporal_2 *= 0.5 * emit_list['Ax'] * transit_list['AB'] * emit_list['By']
        temporal_3 *= 0.5 * emit_list['Bx'] * transit_list['BA'] * emit_list['Ay']
        temporal_4 *= 0.5 * emit_list['Bx'] * transit_list['BB'] * emit_list['By']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Ax']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['Bx']
          alphabet.append('B')
              
      elif interest[i+1] == 'z':
        temporal_1 *= 0.5 * emit_list['Ax'] * transit_list['AA'] * emit_list['Az'] 
        temporal_2 *= 0.5 * emit_list['Ax'] * transit_list['AB'] * emit_list['Bz']
        temporal_3 *= 0.5 * emit_list['Bx'] * transit_list['BA'] * emit_list['Az']
        temporal_4 *= 0.5 * emit_list['Bx'] * transit_list['BB'] * emit_list['Bz']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Ax']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['Bx']
          alphabet.append('B')    
      
      temporal_1 = 1 
      temporal_2 = 1 
      temporal_3 = 1 
      temporal_4 = 1
    
    # Boundary_1_1
    
    elif i == len(interest)-1 :
      
      if alphabet[i-1] == 'A':
        
        temporal_1 *= result * transit_list['AA'] * emit_list['Ax'] 
        temporal_2 *= result * transit_list['AB'] * emit_list['Bx']
        
        A = max(temporal_1, temporal_2)
        
        if A == temporal_1:
          result *= transit_list['AA'] * emit_list['Ax'] 
          alphabet.append('A')
        elif A == temporal_2:
          result *= transit_list['AB'] * emit_list['Bx']
          alphabet.append('B')    
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
                
      
      elif alphabet[i-1] == 'B':
        
        temporal_1 *= result * transit_list['BA'] * emit_list['Ax'] 
        temporal_2 *= result * transit_list['BB'] * emit_list['Bx']
        
        A = max(temporal_1, temporal_2)
        
        if A == temporal_1:
          result *= transit_list['BA'] * emit_list['Ax'] 
          alphabet.append('A')
        elif A == temporal_2:
          result *= transit_list['BB'] * emit_list['Bx']
          alphabet.append('B')    
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
               
      
    
    # Boundary_1_2
    
    else:
      if alphabet[i-1] == 'A':
        
        if interest[i+1] == 'x':
          temporal_1 *= result * transit_list['AA'] * emit_list['Ax'] * transit_list['AA'] * emit_list['Ax'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Ax'] * transit_list['AB'] * emit_list['Bx']
          temporal_3 *= result * transit_list['AB'] * emit_list['Bx'] * transit_list['BA'] * emit_list['Ax']
          temporal_4 *= result * transit_list['AB'] * emit_list['Bx'] * transit_list['BB'] * emit_list['Bx']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Ax']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['Bx']
            alphabet.append('B')
          
        elif interest[i+1] == 'y':
          temporal_1 *= result * transit_list['AA'] * emit_list['Ax'] * transit_list['AA'] * emit_list['Ay'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Ax'] * transit_list['AB'] * emit_list['By']
          temporal_3 *= result * transit_list['AB'] * emit_list['Bx'] * transit_list['BA'] * emit_list['Ay']
          temporal_4 *= result * transit_list['AB'] * emit_list['Bx'] * transit_list['BB'] * emit_list['By']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Ax']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['Bx']
            alphabet.append('B')
              
        elif interest[i+1] == 'z':
          temporal_1 *= result * transit_list['AA'] * emit_list['Ax'] * transit_list['AA'] * emit_list['Az'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Ax'] * transit_list['AB'] * emit_list['Bz']
          temporal_3 *= result * transit_list['AB'] * emit_list['Bx'] * transit_list['BA'] * emit_list['Az']
          temporal_4 *= result * transit_list['AB'] * emit_list['Bx'] * transit_list['BB'] * emit_list['Bz']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Ax']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['Bx']
            alphabet.append('B')   
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
      
      # Boundary_1_3
      
      elif alphabet[i-1] == 'B':
        
        if interest[i+1] == 'x':
          temporal_1 *= result * transit_list['BA'] * emit_list['Ax'] * transit_list['AA'] * emit_list['Ax'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Ax'] * transit_list['AB'] * emit_list['Bx']
          temporal_3 *= result * transit_list['BB'] * emit_list['Bx'] * transit_list['BA'] * emit_list['Ax']
          temporal_4 *= result * transit_list['BB'] * emit_list['Bx'] * transit_list['BB'] * emit_list['Bx']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Ax']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['Bx']
            alphabet.append('B')
          
        elif interest[i+1] == 'y':
          temporal_1 *= result * transit_list['BA'] * emit_list['Ax'] * transit_list['AA'] * emit_list['Ay'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Ax'] * transit_list['AB'] * emit_list['By']
          temporal_3 *= result * transit_list['BB'] * emit_list['Bx'] * transit_list['BA'] * emit_list['Ay']
          temporal_4 *= result * transit_list['BB'] * emit_list['Bx'] * transit_list['BB'] * emit_list['By']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Ax']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['Bx']
            alphabet.append('B')
              
        elif interest[i+1] == 'z':
          temporal_1 *= result * transit_list['BA'] * emit_list['Ax'] * transit_list['AA'] * emit_list['Az'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Ax'] * transit_list['AB'] * emit_list['Bz']
          temporal_3 *= result * transit_list['BB'] * emit_list['Bx'] * transit_list['BA'] * emit_list['Az']
          temporal_4 *= result * transit_list['BB'] * emit_list['Bx'] * transit_list['BB'] * emit_list['Bz']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Ax']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['Bx']
            alphabet.append('B')   
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
      
      
      
  # Boundary_2_0
  
  elif interest[i] == 'y':
    if i == 0:
      if interest[i+1] == 'x':
        temporal_1 *= 0.5 * emit_list['Ay'] * transit_list['AA'] * emit_list['Ax'] 
        temporal_2 *= 0.5 * emit_list['Ay'] * transit_list['AB'] * emit_list['Bx']
        temporal_3 *= 0.5 * emit_list['By'] * transit_list['BA'] * emit_list['Ax']
        temporal_4 *= 0.5 * emit_list['By'] * transit_list['BB'] * emit_list['Bx']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Ay']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['By']
          alphabet.append('B')
          
      elif interest[i+1] == 'y':
        temporal_1 *= 0.5 * emit_list['Ay'] * transit_list['AA'] * emit_list['Ay'] 
        temporal_2 *= 0.5 * emit_list['Ay'] * transit_list['AB'] * emit_list['By']
        temporal_3 *= 0.5 * emit_list['By'] * transit_list['BA'] * emit_list['Ay']
        temporal_4 *= 0.5 * emit_list['By'] * transit_list['BB'] * emit_list['By']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Ay']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['By']
          alphabet.append('B')
              
      elif interest[i+1] == 'z':
        temporal_1 *= 0.5 * emit_list['Ay'] * transit_list['AA'] * emit_list['Az'] 
        temporal_2 *= 0.5 * emit_list['Ay'] * transit_list['AB'] * emit_list['Bz']
        temporal_3 *= 0.5 * emit_list['By'] * transit_list['BA'] * emit_list['Az']
        temporal_4 *= 0.5 * emit_list['By'] * transit_list['BB'] * emit_list['Bz']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Ay']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['By']
          alphabet.append('B')    
      
      temporal_1 = 1 
      temporal_2 = 1 
      temporal_3 = 1 
      temporal_4 = 1
    
    # Boundary_2_1
    
    elif i == len(interest)-1 :
      
      if alphabet[i-1] == 'A':
        
        temporal_1 *= result * transit_list['AA'] * emit_list['Ay'] 
        temporal_2 *= result * transit_list['AB'] * emit_list['By']
        
        A = max(temporal_1, temporal_2)
        
        if A == temporal_1:
          result *= transit_list['AA'] * emit_list['Ay'] 
          alphabet.append('A')
        elif A == temporal_2:
          result *= transit_list['AB'] * emit_list['By']
          alphabet.append('B')    
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
                
      
      elif alphabet[i-1] == 'B':
        
        temporal_1 *= result * transit_list['BA'] * emit_list['Ay'] 
        temporal_2 *= result * transit_list['BB'] * emit_list['By']
        
        A = max(temporal_1, temporal_2)
        
        if A == temporal_1:
          result *= transit_list['BA'] * emit_list['Ay'] 
          alphabet.append('A')
        elif A == temporal_2:
          result *= transit_list['BB'] * emit_list['By']
          alphabet.append('B')    
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
      
    
    # Boundary_2_2
    
    else:
      if alphabet[i-1] == 'A':
        
        if interest[i+1] == 'x':
          temporal_1 *= result * transit_list['AA'] * emit_list['Ay'] * transit_list['AA'] * emit_list['Ax'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Ay'] * transit_list['AB'] * emit_list['Bx']
          temporal_3 *= result * transit_list['AB'] * emit_list['By'] * transit_list['BA'] * emit_list['Ax']
          temporal_4 *= result * transit_list['AB'] * emit_list['By'] * transit_list['BB'] * emit_list['Bx']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Ay']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['By']
            alphabet.append('B')
          
        elif interest[i+1] == 'y':
          temporal_1 *= result * transit_list['AA'] * emit_list['Ay'] * transit_list['AA'] * emit_list['Ay'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Ay'] * transit_list['AB'] * emit_list['By']
          temporal_3 *= result * transit_list['AB'] * emit_list['By'] * transit_list['BA'] * emit_list['Ay']
          temporal_4 *= result * transit_list['AB'] * emit_list['By'] * transit_list['BB'] * emit_list['By']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Ay']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['By']
            alphabet.append('B')
              
        elif interest[i+1] == 'z':
          temporal_1 *= result * transit_list['AA'] * emit_list['Ay'] * transit_list['AA'] * emit_list['Az'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Ay'] * transit_list['AB'] * emit_list['Bz']
          temporal_3 *= result * transit_list['AB'] * emit_list['By'] * transit_list['BA'] * emit_list['Az']
          temporal_4 *= result * transit_list['AB'] * emit_list['By'] * transit_list['BB'] * emit_list['Bz']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Ay']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['By']
            alphabet.append('B')   
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
      
      # Boundary_2_3
      
      elif alphabet[i-1] == 'B':
        
        if interest[i+1] == 'x':
          temporal_1 *= result * transit_list['BA'] * emit_list['Ay'] * transit_list['AA'] * emit_list['Ax'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Ay'] * transit_list['AB'] * emit_list['Bx']
          temporal_3 *= result * transit_list['BB'] * emit_list['By'] * transit_list['BA'] * emit_list['Ax']
          temporal_4 *= result * transit_list['BB'] * emit_list['By'] * transit_list['BB'] * emit_list['Bx']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Ay']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['By']
            alphabet.append('B')
          
        elif interest[i+1] == 'y':
          temporal_1 *= result * transit_list['BA'] * emit_list['Ay'] * transit_list['AA'] * emit_list['Ay'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Ay'] * transit_list['AB'] * emit_list['By']
          temporal_3 *= result * transit_list['BB'] * emit_list['By'] * transit_list['BA'] * emit_list['Ay']
          temporal_4 *= result * transit_list['BB'] * emit_list['By'] * transit_list['BB'] * emit_list['By']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Ay']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['By']
            alphabet.append('B')
              
        elif interest[i+1] == 'z':
          temporal_1 *= result * transit_list['BA'] * emit_list['Ay'] * transit_list['AA'] * emit_list['Az'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Ay'] * transit_list['AB'] * emit_list['Bz']
          temporal_3 *= result * transit_list['BB'] * emit_list['By'] * transit_list['BA'] * emit_list['Az']
          temporal_4 *= result * transit_list['BB'] * emit_list['By'] * transit_list['BB'] * emit_list['Bz']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Ay']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['By']
            alphabet.append('B')   
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
    
      
  
  
  
  
  
  
  #Boundary_3_0
  
  elif interest[i] == 'z':
    if i == 0:
      if interest[i+1] == 'x':
        temporal_1 *= 0.5 * emit_list['Az'] * transit_list['AA'] * emit_list['Ax'] 
        temporal_2 *= 0.5 * emit_list['Az'] * transit_list['AB'] * emit_list['Bx']
        temporal_3 *= 0.5 * emit_list['Bz'] * transit_list['BA'] * emit_list['Ax']
        temporal_4 *= 0.5 * emit_list['Bz'] * transit_list['BB'] * emit_list['Bx']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Az']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['Bz']
          alphabet.append('B')
          
      elif interest[i+1] == 'y':
        temporal_1 *= 0.5 * emit_list['Az'] * transit_list['AA'] * emit_list['Ay'] 
        temporal_2 *= 0.5 * emit_list['Az'] * transit_list['AB'] * emit_list['By']
        temporal_3 *= 0.5 * emit_list['Bz'] * transit_list['BA'] * emit_list['Ay']
        temporal_4 *= 0.5 * emit_list['Bz'] * transit_list['BB'] * emit_list['By']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Az']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['Bz']
          alphabet.append('B')
              
      elif interest[i+1] == 'z':
        temporal_1 *= 0.5 * emit_list['Az'] * transit_list['AA'] * emit_list['Az'] 
        temporal_2 *= 0.5 * emit_list['Az'] * transit_list['AB'] * emit_list['Bz']
        temporal_3 *= 0.5 * emit_list['Bz'] * transit_list['BA'] * emit_list['Az']
        temporal_4 *= 0.5 * emit_list['Bz'] * transit_list['BB'] * emit_list['Bz']
        
        A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
        if A == temporal_1 or A == temporal_2:
          result *= 0.5 * emit_list['Az']
          alphabet.append('A')
        elif A == temporal_3 or A == temporal_4:
          result *= 0.5 * emit_list['Bz']
          alphabet.append('B')    
      
      temporal_1 = 1 
      temporal_2 = 1 
      temporal_3 = 1 
      temporal_4 = 1
    
    # Boundary_3_1
    
    elif i == len(interest)-1 :
      
      if alphabet[i-1] == 'A':
        
        temporal_1 *= result * transit_list['AA'] * emit_list['Az'] 
        temporal_2 *= result * transit_list['AB'] * emit_list['Bz']
        
        A = max(temporal_1, temporal_2)
        
        if A == temporal_1:
          result *= transit_list['AA'] * emit_list['Az'] 
          alphabet.append('A')
        elif A == temporal_2:
          result *= transit_list['AB'] * emit_list['Bz']
          alphabet.append('B')    
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
                
      
      elif alphabet[i-1] == 'B':
        
        temporal_1 *= result * transit_list['BA'] * emit_list['Az'] 
        temporal_2 *= result * transit_list['BB'] * emit_list['Bz']
        
        A = max(temporal_1, temporal_2)
        
        if A == temporal_1:
          result *= transit_list['BA'] * emit_list['Az'] 
          alphabet.append('A')
        elif A == temporal_2:
          result *= transit_list['BB'] * emit_list['Bz']
          alphabet.append('B')    
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
      
    
    # Boundary_3_2
    
    else:
      if alphabet[i-1] == 'A':
        
        if interest[i+1] == 'x':
          temporal_1 *= result * transit_list['AA'] * emit_list['Az'] * transit_list['AA'] * emit_list['Ax'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Az'] * transit_list['AB'] * emit_list['Bx']
          temporal_3 *= result * transit_list['AB'] * emit_list['Bz'] * transit_list['BA'] * emit_list['Ax']
          temporal_4 *= result * transit_list['AB'] * emit_list['Bz'] * transit_list['BB'] * emit_list['Bx']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Az']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['Bz']
            alphabet.append('B')
          
        elif interest[i+1] == 'y':
          temporal_1 *= result * transit_list['AA'] * emit_list['Az'] * transit_list['AA'] * emit_list['Ay'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Az'] * transit_list['AB'] * emit_list['By']
          temporal_3 *= result * transit_list['AB'] * emit_list['Bz'] * transit_list['BA'] * emit_list['Ay']
          temporal_4 *= result * transit_list['AB'] * emit_list['Bz'] * transit_list['BB'] * emit_list['By']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Az']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['Bz']
            alphabet.append('B')
              
        elif interest[i+1] == 'z':
          temporal_1 *= result * transit_list['AA'] * emit_list['Az'] * transit_list['AA'] * emit_list['Az'] 
          temporal_2 *= result * transit_list['AA'] * emit_list['Az'] * transit_list['AB'] * emit_list['Bz']
          temporal_3 *= result * transit_list['AB'] * emit_list['Bz'] * transit_list['BA'] * emit_list['Az']
          temporal_4 *= result * transit_list['AB'] * emit_list['Bz'] * transit_list['BB'] * emit_list['Bz']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['AA'] * emit_list['Az']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['AB'] * emit_list['Bz']
            alphabet.append('B')   
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1
      
      # Boundary_3_3
      
      elif alphabet[i-1] == 'B':
        
        if interest[i+1] == 'x':
          temporal_1 *= result * transit_list['BA'] * emit_list['Az'] * transit_list['AA'] * emit_list['Ax'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Az'] * transit_list['AB'] * emit_list['Bx']
          temporal_3 *= result * transit_list['BB'] * emit_list['Bz'] * transit_list['BA'] * emit_list['Ax']
          temporal_4 *= result * transit_list['BB'] * emit_list['Bz'] * transit_list['BB'] * emit_list['Bx']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Az']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['Bz']
            alphabet.append('B')
          
        elif interest[i+1] == 'y':
          temporal_1 *= result * transit_list['BA'] * emit_list['Az'] * transit_list['AA'] * emit_list['Ay'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Az'] * transit_list['AB'] * emit_list['By']
          temporal_3 *= result * transit_list['BB'] * emit_list['Bz'] * transit_list['BA'] * emit_list['Ay']
          temporal_4 *= result * transit_list['BB'] * emit_list['Bz'] * transit_list['BB'] * emit_list['By']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Az']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['Bz']
            alphabet.append('B')
              
        elif interest[i+1] == 'z':
          temporal_1 *= result * transit_list['BA'] * emit_list['Az'] * transit_list['AA'] * emit_list['Az'] 
          temporal_2 *= result * transit_list['BA'] * emit_list['Az'] * transit_list['AB'] * emit_list['Bz']
          temporal_3 *= result * transit_list['BB'] * emit_list['Bz'] * transit_list['BA'] * emit_list['Az']
          temporal_4 *= result * transit_list['BB'] * emit_list['Bz'] * transit_list['BB'] * emit_list['Bz']
        
          A = max(temporal_1, temporal_2, temporal_3, temporal_4)
        
          if A == temporal_1 or A == temporal_2:
            result *= transit_list['BA'] * emit_list['Az']
            alphabet.append('A')
          elif A == temporal_3 or A == temporal_4:
            result *= transit_list['BB'] * emit_list['Bz']
            alphabet.append('B')   
      
        temporal_1 = 1 
        temporal_2 = 1 
        temporal_3 = 1 
        temporal_4 = 1

#print(result)


hi = ""
for i in range(len(alphabet)):
  hi += alphabet[i]
  
print(hi)
# Out:
# A   0.117   0.691   0.192
# B   0.097   0.42   0.483
# {'AA': 0.641, 'AB': 0.359, 'BA': 0.729, 'BB': 0.271}
# {'Ax': 0.117, 'Ay': 0.691, 'Az': 0.192, 'Bx': 0.097, 'By': 0.42, 'Bz': 0.483}
# AAABBAAAAA
